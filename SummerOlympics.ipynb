# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('summer.csv')
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
df.isnull().sum()
# since country column was not required in the given question, thus, neglecting the 4 null values in country column.
# Out:
# Year          0
# City          0
# Sport         0
# Discipline    0
# Athlete       0
# Country       4
# Gender        0
# Event         0
# Medal         0
# dtype: int64

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
df['City']
# Out:
# 0        Athens
# 1        Athens
# 2        Athens
# 3        Athens
# 4        Athens
#           ...
# 31160    London
# 31161    London
# 31162    London
# 31163    London
# 31164    London
# Name: City, Length: 31165, dtype: object

# %%
df['City'].unique()
# Out:
# array(['Athens', 'Paris', 'St Louis', 'London', 'Stockholm', 'Antwerp',
#        'Amsterdam', 'Los Angeles', 'Berlin', 'Helsinki',
#        'Melbourne / Stockholm', 'Rome', 'Tokyo', 'Mexico', 'Munich',
#        'Montreal', 'Moscow', 'Seoul', 'Barcelona', 'Atlanta', 'Sydney',
#        'Beijing'], dtype=object)

# %%
len(df['City'].unique())
#In 22 cities summer olympics had been held so far.
# Out:
# 22

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
df1 = df[df['Medal'] == 'Gold']
df1
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
df1['Discipline'].unique()
# Out:
# array(['Swimming', 'Athletics', 'Cycling Road', 'Cycling Track',
#        'Fencing', 'Artistic G.', 'Shooting', 'Tennis', 'Weightlifting',
#        'Wrestling Gre-R', 'Water polo', 'Archery', 'Basque Pelota',
#        'Cricket', 'Croquet', 'Jumping', 'Football', 'Golf', 'Polo',
#        'Rowing', 'Rugby', 'Sailing', 'Tug of War', 'Diving', 'Boxing',
#        'Lacrosse', 'Roque', 'Wrestling Free.', 'Hockey', 'Jeu de Paume',
#        'Rackets', 'Figure skating', 'Water Motorspor', 'Dressage',
#        'Eventing', 'Modern Pentath.', 'Vaulting', 'Ice Hockey',
#        'Basketball', 'Canoe / Kayak F', 'Handball', 'Judo', 'Volleyball',
#        'Canoe / Kayak S', 'Synchronized S.', 'Rhythmic G.',
#        'Table Tennis', 'Badminton', 'Baseball', 'Mountain Bike',
#        'Softball', 'Beach volley.', 'Trampoline', 'Taekwondo',
#        'Triathlon', 'BMX', 'Marathon swimming', 'Synchronized Swimming',
#        'Water Polo', 'Canoe Slalom', 'Canoe Sprint', 'Cycling BMX',
# ...

# %%
len(df1['Discipline'].unique())
# Out:
# 67

# %%
for Discipline in df1['Discipline'].unique():
    print([Discipline , len(df1[df1['Discipline']  == Discipline])])
# Out:
# ['Swimming', 901]
# ['Athletics', 1215]
# ['Cycling Road', 107]
# ['Cycling Track', 250]
# ['Fencing', 552]
# ['Artistic G.', 752]
# ['Shooting', 384]
# ['Tennis', 92]
# ['Weightlifting', 200]
# ['Wrestling Gre-R', 180]
# ['Water polo', 299]
# ['Archery', 126]
# ['Basque Pelota', 2]
# ['Cricket', 12]
# ['Croquet', 4]
# ['Jumping', 114]
# ['Football', 503]
# ['Golf', 13]
# ['Polo', 22]
# ['Rowing', 890]
# ['Rugby', 78]
# ['Sailing', 412]
# ['Tug of War', 36]
# ['Diving', 130]
# ['Boxing', 239]
# ['Lacrosse', 28]
# ['Roque', 1]
# ['Wrestling Free.', 193]
# ['Hockey', 486]
# ['Jeu de Paume', 1]
# ['Rackets', 3]
# ['Figure skating', 9]
# ['Water Motorspor', 5]
# ['Dressage', 88]
# ['Eventing', 112]
# ['Modern Pentath.', 58]
# ['Vaulting', 6]
# ['Ice Hockey', 8]
# ['Basketball', 342]
# ['Canoe / Kayak F', 304]
# ['Handball', 321]
# ['Judo', 123]
# ['Volleyball', 312]
# ['Canoe / Kayak S', 30]
# ['Synchronized S.', 52]
# ['Rhythmic G.', 31]
# ['Table Tennis', 46]
# ['Badminton', 46]
# ...

# %%
data = []
for Discipline in df1['Discipline'].unique():
    data.append([Discipline , len(df1[df1['Discipline']  == Discipline])])
    
data = pd.DataFrame(data, columns = ['Discipline','No. of Gold Medal'])

# %%
data.sort_values(by = 'No. of Gold Medal', ascending = False).head()
# Out:
#      Discipline  No. of Gold Medal
# 1     Athletics               1215
# 0      Swimming                901
# 19       Rowing                890
# 5   Artistic G.                752
# 4       Fencing                552

# %%
pd.DataFrame(data,columns = ['Discipline','No. of Gold Medal']).sort_values(by='No. of Gold Medal', ascending=False).head().plot(x = 'Discipline', y = 'No. of Gold Medal', kind = 'bar', figsize = (8,6))
# Out:
# <AxesSubplot:xlabel='Discipline'>

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
for Discipline in df['Discipline'].unique():
    print([Discipline , len(df[df['Discipline']  == Discipline])])
# Out:
# ['Swimming', 2628]
# ['Athletics', 3638]
# ['Cycling Road', 315]
# ['Cycling Track', 748]
# ['Fencing', 1613]
# ['Artistic G.', 2103]
# ['Shooting', 1150]
# ['Tennis', 296]
# ['Weightlifting', 593]
# ['Wrestling Gre-R', 549]
# ['Water polo', 880]
# ['Archery', 329]
# ['Basque Pelota', 4]
# ['Cricket', 24]
# ['Croquet', 8]
# ['Jumping', 327]
# ['Football', 1497]
# ['Golf', 30]
# ['Polo', 66]
# ['Rowing', 2667]
# ['Rugby', 192]
# ['Sailing', 1109]
# ['Tug of War', 94]
# ['Diving', 392]
# ['Boxing', 894]
# ['Lacrosse', 59]
# ['Roque', 3]
# ['Wrestling Free.', 591]
# ['Hockey', 1422]
# ['Jeu de Paume', 3]
# ['Rackets', 10]
# ['Figure skating', 27]
# ['Water Motorspor', 5]
# ['Dressage', 267]
# ['Eventing', 331]
# ['Modern Pentath.', 174]
# ['Vaulting', 14]
# ['Ice Hockey', 27]
# ['Basketball', 1012]
# ['Canoe / Kayak F', 912]
# ['Handball', 973]
# ['Judo', 491]
# ['Volleyball', 934]
# ['Canoe / Kayak S', 90]
# ['Synchronized S.', 153]
# ['Rhythmic G.', 93]
# ['Table Tennis', 144]
# ...

# %%
data1 = []
for Discipline in df['Discipline'].unique():
    data1.append([Discipline , len(df[df['Discipline']  == Discipline])])
    
data1 = pd.DataFrame(data1, columns = ['Discipline','No. of Medals'])
data1.sort_values(by = 'No. of Medals', ascending = False).head()
# Out:
#      Discipline  No. of Medals
# 1     Athletics           3638
# 19       Rowing           2667
# 0      Swimming           2628
# 5   Artistic G.           2103
# 4       Fencing           1613

# %%
pd.DataFrame(data1,columns = ['Discipline','No. of Medals']).sort_values(by='No. of Medals', ascending=False).head().plot(x = 'Discipline', y = 'No. of Medals', kind = 'bar', figsize = (7,5))
# Out:
# <AxesSubplot:xlabel='Discipline'>

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
df['Athlete'].unique()
# Out:
# array(['HAJOS, Alfred', 'HERSCHMANN, Otto', 'DRIVAS, Dimitrios', ...,
#        'TOTROV, Rustam', 'ALEKSANYAN, Artur', 'LIDBERG, Jimmy'],
#       dtype=object)

# %%
len(df['Athlete'].unique())
# Out:
# 22762

# %%
data2 = []
for Athlete in df['Athlete'].unique():
    data2.append([Athlete,len(df[df['Athlete'] == Athlete])])
    
data2 = pd.DataFrame(data2, columns = ['Athlete','No. of Medals'])
data2.sort_values(by = 'No. of Medals', ascending = False).head()
# Out:
#                     Athlete  No. of Medals
# 18640       PHELPS, Michael             22
# 7197       LATYNINA, Larisa             18
# 9948     ANDRIANOV, Nikolay             15
# 6591           ONO, Takashi             13
# 5103   MANGIAROTTI, Edoardo             13

# %%
pd.DataFrame(data2,columns = ['Athlete','No. of Medals']).sort_values(by='No. of Medals', ascending=False).head().plot(x = 'Athlete', y = 'No. of Medals', kind = 'bar', figsize = (7,5))
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
df1
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
data3 = []
for Athlete in df1['Athlete'].unique():
    data3.append([Athlete,len(df1[df1['Athlete'] == Athlete])])
    
data3 = pd.DataFrame(data3, columns = ['Athlete','No. of Gold Medals'])
data3.sort_values(by = 'No. of Gold Medals', ascending = False).head()
# Out:
#                Athlete  No. of Gold Medals
# 6851   PHELPS, Michael                  18
# 3320       SPITZ, Mark                   9
# 2714  LATYNINA, Larisa                   9
# 4630       LEWIS, Carl                   9
# 907       NURMI, Paavo                   9

# %%
pd.DataFrame(data3,columns = ['Athlete','No. of Gold Medals']).sort_values(by='No. of Gold Medals', ascending=False).head().plot(x = 'Athlete', y = 'No. of Gold Medals', kind = 'bar', figsize = (6,4))
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
df1['Country'].unique()
# Out:
# array(['HUN', 'GRE', 'AUT', 'USA', 'AUS', 'FRA', 'GER', 'SUI', 'ZZX',
#        'GBR', 'DEN', 'BEL', 'CAN', 'ESP', 'ITA', 'CUB', 'SWE', 'RSA',
#        'ANZ', 'NOR', 'RU1', 'FIN', 'NED', 'BRA', 'EST', 'URU', 'YUG',
#        'TCH', 'ARG', 'JPN', 'POL', 'IRL', 'NZL', 'IND', 'EGY', 'TUR',
#        'JAM', 'MEX', 'PER', 'LUX', 'URS', 'ROU', 'EUA', 'IRI', 'BUL',
#        'ETH', 'PAK', 'BAH', 'GDR', 'KEN', 'TUN', 'FRG', 'VEN', 'UGA',
#        'PRK', 'TRI', 'KOR', 'ZIM', 'CHN', 'MAR', 'POR', 'SUR', 'EUN',
#        'ALG', 'LTU', 'INA', 'RUS', 'CRC', 'ECU', 'BDI', 'SYR', 'CZE',
#        'NGR', 'UKR', 'THA', 'KAZ', 'SVK', 'CRO', 'BLR', 'HKG', 'ARM',
#        'MOZ', 'UZB', 'CMR', 'LAT', 'SLO', 'AZE', 'COL', 'DOM', 'GEO',
#        'ISR', 'UAE', 'TPE', 'CHI', 'PAN', 'MGL', nan, 'GRN', 'TTO', 'SRB'],
#       dtype=object)

# %%
df1.isnull().sum()
# Neglecting the 2 null country in country column
# Out:
# Year          0
# City          0
# Sport         0
# Discipline    0
# Athlete       0
# Country       2
# Gender        0
# Event         0
# Medal         0
# dtype: int64

# %%
df2 = df1[df1['Country'] == 'IND']
df2
# Out:
#        Year       City     Sport Discipline                       Athlete  \
# 5512   1928  Amsterdam    Hockey     Hockey          ALLEN, Richard James
# 5513   1928  Amsterdam    Hockey     Hockey                   CHAND, Dyan
# 5514   1928  Amsterdam    Hockey     Hockey           GATELEY, Maurice A.
# 5515   1928  Amsterdam    Hockey     Hockey                   GILL, K. S.
# 5516   1928  Amsterdam    Hockey     Hockey  GOODSIR-CULLEN, William John
# ...     ...        ...       ...        ...                           ...
# 16099  1980     Moscow    Hockey     Hockey                  SINGH, Singh
# 16100  1980     Moscow    Hockey     Hockey               SURINDER, Singh
# 16101  1980     Moscow    Hockey     Hockey           SYLVANUS, Dung Dung
# 16102  1980     Moscow    Hockey     Hockey                  ZAFAR, Zafar
# 28856  2008    Beijing  Shooting   Shooting               BINDRA, Abhinav
#
#       Country Gender                     Event Medal
# ...

# %%
df2['Year'].min()
#First Gold Medal in Summer Olympics by India was in Year
# Out:
# 1928

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
len(df['Athlete'].unique())
# Out:
# 22762

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
data4 = []

for Event in df['Event'].unique():
    data4.append([Event , len(df[df['Event']  == Event])])

data4 = pd.DataFrame(data4,columns = ['Event','No. of Players'])
pd.DataFrame(data4,columns = ['Event','No. of Players']).sort_values(by='No. of Players', ascending=False).head().plot(x = 'Event', y = 'No. of Players', kind = 'bar', figsize = (6,4))
# Out:
# <AxesSubplot:xlabel='Event'>

# %%
data4.sort_values(by='No. of Players', ascending=False).head()
# Out:
#                 Event  No. of Players
# 80           Football            1497
# 176            Hockey            1422
# 138  Team Competition            1147
# 327        Basketball            1012
# 337          Handball             973

# %%
data4['No. of Players'].max()
# Out:
# 1497

# %%
data4[data4['No. of Players'] == 1497]
#Most Popular event in terms of player
# Out:
#        Event  No. of Players
# 80  Football            1497

# %% [markdown]
# ### Another way of displaying the same

# %%
data4.sort_values(by='No. of Players', ascending=False).head(1)
#Most Popular event in terms of player
# Out:
#        Event  No. of Players
# 80  Football            1497

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
df1
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
df1['Gender'].unique()
# Out:
# array(['Men', 'Women'], dtype=object)

# %%
df4 = df1[df1['Gender'] == 'Women']
df4
# Out:
#        Year      City          Sport           Discipline  \
# 417    1900     Paris           Golf                 Golf
# 641    1900     Paris         Tennis               Tennis
# 649    1900     Paris         Tennis               Tennis
# 710    1904  St Louis        Archery              Archery
# 713    1904  St Louis        Archery              Archery
# ...     ...       ...            ...                  ...
# 31081  2012    London  Weightlifting        Weightlifting
# 31097  2012    London      Wrestling  Wrestling Freestyle
# 31105  2012    London      Wrestling  Wrestling Freestyle
# 31113  2012    London      Wrestling  Wrestling Freestyle
# 31121  2012    London      Wrestling  Wrestling Freestyle
#
#                      Athlete Country Gender  \
# 417    ABBOTT, Margaret Ives     USA  Women
# 641        COOPER, Charlotte     GBR  Women
# 649        COOPER, Charlotte     GBR  Women
# 710    HOWELL, Matilda Scott     USA  Women
# ...

# %%
data5 = []

for Sport in df4['Sport'].unique():
    data5.append([Sport , len(df4[df4['Sport']  == Sport])])

data5 = pd.DataFrame(data5,columns = ['Sport','No. of Players'])
pd.DataFrame(data5,columns = ['Sport','No. of Players']).sort_values(by='No. of Players', ascending=False).plot(x = 'Sport', y = 'No. of Players', kind = 'bar', figsize = (20,5))
# Out:
# <AxesSubplot:xlabel='Sport'>

# %%
data5.sort_values(by='No. of Players', ascending=False).head()
# Out:
#          Sport  No. of Players
# 4     Aquatics             589
# 7    Athletics             389
# 8   Gymnastics             268
# 14      Rowing             217
# 11  Volleyball             166

# %%
data5['No. of Players'].max()
# Out:
# 589

# %%
data5[data5['No. of Players'] == 589]
#Sports having most number of Female Gold Medalists
# Out:
#       Sport  No. of Players
# 4  Aquatics             589

# %% [markdown]
# ### Another way of showing the same

# %%
data5.sort_values(by='No. of Players', ascending=False).head(1)
# Out:
#       Sport  No. of Players
# 4  Aquatics             589
